# %% [markdown]
# ### ¿Por qué Pandas?
# Pandas está enfocada a la manipulación y análisis de datos.
#
# Al estar construido sobre NumPy es muy veloz. Requiere poco código para manipular los datos. Soporta múltiples formatos de archivos. Ordena los datos en una alineación inteligente. Se pueden manejar grandes cantidades de datos, hacer analítica y crear dahsboards.
#
# La forma de importar estas librerías es de la siguiente manera:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ![image-5.png](attachment:image-5.png)
# ![image-4.png](attachment:image-4.png)

# %%
MarcasDeportivas = pd.Series(["Adidas", "Reebok", "Topper", "Nike"])
MarcasDeportivas
# Out:
# 0    Adidas
# 1    Reebok
# 2    Topper
# 3      Nike
# dtype: object

# %%
#si quiero definir yo el índice
MarcasDeportivas = pd.Series(["Adidas", "Reebok", "Topper", "Nike"], index=[1,3,5,7])
MarcasDeportivas
# Out:
# 1    Adidas
# 3    Reebok
# 5    Topper
# 7      Nike
# dtype: object

# %%
#otra forma de definir una serie es a traves de un diccionario
dict = {1:"Adidas", 3:"Reebok", 5:"Topper", 7:"Nike"}
pd.Series(dict)
# Out:
# 1    Adidas
# 3    Reebok
# 5    Topper
# 7      Nike
# dtype: object

# %%
MarcasDeportivas[1] #puedo entrar a los objetos de la serie a través del índice igual que en Numpy
# Out:
# 'Adidas'

# %%
MarcasDeportivas[0:2] #también puedo hacer slicing
# Out:
# 1    Adidas
# 3    Reebok
# dtype: object

# %%
#creando un dataframe
dict = {"Marcas": ["Adidas", "Reebok", "Topper", "Nike"],
"Prendas": ["zapatillas", "calzas", "medias", "gorras"]
}

# %%
dfMarcasDeportivas =pd.DataFrame(dict, index= [1,3,5,7])

# %%
dfMarcasDeportivas
# Out:
#    Marcas     Prendas
# 1  Adidas  zapatillas
# 3  Reebok      calzas
# 5  Topper      medias
# 7    Nike      gorras

# %%
dfMarcasDeportivas.columns
# Out:
# Index(['Marcas', 'Prendas'], dtype='object')

# %%
dfMarcasDeportivas.index
# Out:
# Int64Index([1, 3, 5, 7], dtype='int64')

# %%
jugadores_granada = {'Jugador':['Luis Suárez','Jorge Molina', 'Antonio Puertas', 'Germán Sánchez', 'Luis Milla', 
'Luís Manuel Arantes Maximiano'],

'Posición':['Delantero', 'Delantero', 'Centrocampista', 'Defensa', 'Centrocampista', 'Portero'],

'Número':[9, 23, 10, 6, 5, 1],

'Altura':[185.0, 187.0, 185.0, 187.0, 175.0, 190.0],

'Goles':[7, 7, 5, 2, 2, 0]
}

# %%
df = pd.DataFrame(jugadores_granada)
df
# Out:
#                          Jugador        Posición  Número  Altura  Goles
# 0                    Luis Suárez       Delantero       9   185.0      7
# 1                   Jorge Molina       Delantero      23   187.0      7
# 2                Antonio Puertas  Centrocampista      10   185.0      5
# 3                 Germán Sánchez         Defensa       6   187.0      2
# 4                     Luis Milla  Centrocampista       5   175.0      2
# 5  Luís Manuel Arantes Maximiano         Portero       1   190.0      0

# %%
delanteros = df[df["Posición"] == "Delantero"] 
delanteros
# Out:
#         Jugador   Posición  Número  Altura  Goles
# 0   Luis Suárez  Delantero       9   185.0      7
# 1  Jorge Molina  Delantero      23   187.0      7

# %%
jugadores_altos = df[df["Altura"] > 185.0]
jugadores_altos
# Out:
#                          Jugador   Posición  Número  Altura  Goles
# 1                   Jorge Molina  Delantero      23   187.0      7
# 3                 Germán Sánchez    Defensa       6   187.0      2
# 5  Luís Manuel Arantes Maximiano    Portero       1   190.0      0

# %%
goleadores = df[df["Goles"] > 5]
goleadores
# Out:
#         Jugador   Posición  Número  Altura  Goles
# 0   Luis Suárez  Delantero       9   185.0      7
# 1  Jorge Molina  Delantero      23   187.0      7

# %%
#para leer un archivo csv
#https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
df_books = pd.read_csv("C:/Users/Daniela/PLATZI/bestsellers-with-categories_.csv", sep = ",", header = 0)
df_books.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
#leer un archivo json no estructurado... es 
# parecido a un diccionario con llave valor
df_characters = pd.read_json("C:/Users/Daniela/PLATZI//hpcharactersdataraw_.json")
df_characters
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
#Cuando queramos leer una tabla que está en una página web, 
# podemos utilizar la sentencia:
#pd.read_html('link')

# %% [markdown]
# ### Loc e iloc
# Cuando queremos navegar por un dataFrame estas funciones permiten filtrar datos de manera más específica
#
# .loc
# Filtra según un label / etiqueta
#
# .iloc
# Filtra mediante índices.

# %% [markdown]
# https://static.platzi.com/media/user_upload/Pandas-selections-and-indexing-5c4799de-e6df-4eae-bbe9-151a00f820af.jpg

# %%
df_books.loc[0:4, ["Name", "Author"]]
# Out:
#                                                 Name                    Author
# 0                      10-Day Green Smoothie Cleanse                  JJ Smith
# 1                                  11/22/63: A Novel              Stephen King
# 2            12 Rules for Life: An Antidote to Chaos        Jordan B. Peterson
# 3                             1984 (Signet Classics)             George Orwell
# 4  5,000 Awesome Facts (About Everything!) (Natio...  National Geographic Kids

# %%
df_books.loc[:, ["Reviews"]]
# Out:
#      Reviews
# 0      17350
# 1       2052
# 2      18979
# 3      21424
# 4       7665
# ..       ...
# 545     9413
# 546    14331
# 547    14331
# 548    14331
# 549    14331
#
# [550 rows x 1 columns]

# %%
df_books.loc[:, ["Author"]] == "JJ Smith"
# Out:
#      Author
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...
# 545   False
# 546   False
# 547   False
# 548   False
# 549   False
#
# [550 rows x 1 columns]

# %%
df_books.iloc[:, 0:3] #exploro el dataframe según los indices con iloc, extraigo todas las filas y las columnas de índice 0 a 3
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ...

# %% [markdown]
# ### Eliminar columnas de un dataframe con drop

# %%
#para borrar una columna de la salida pero no del df
#para borrar la columna del df tengo que poner inplace=True
df_books.drop("Genre", axis =1).head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
del df_books["Price"]

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year
# 0                    JJ Smith          4.7    17350  2016
# 1                Stephen King          4.6     2052  2011
# 2          Jordan B. Peterson          4.7    18979  2018
# 3               George Orwell          4.7    21424  2017
# ...

# %%
#elimino la fila 0 (indico que es la fila con axis= 0)
df_books.drop(0, axis=0).head(2)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Year
# 1     2052  2011
# 2    18979  2018

# %%
df_books.drop(range(0,10), axis=0).head(2)
# Out:
#                                                  Name            Author  \
# 10                          A Man Called Ove: A Novel   Fredrik Backman
# 11  A Patriot's History of the United States: From...  Larry Schweikart
#
#     User Rating  Reviews  Year
# 10          4.6    23848  2017
# 11          4.6      460  2010

# %%
df_books.head(2) #los cambios anteriores no se hicieron en el df porque no puse inplace
# Out:
#                             Name        Author  User Rating  Reviews  Year
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350  2016
# 1              11/22/63: A Novel  Stephen King          4.6     2052  2011

# %% [markdown]
# ### Crear una nueva columna en el df

# %%
df_books["Nueva_Columna"] = np.nan
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Year  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350  2016
# 1              11/22/63: A Novel  Stephen King          4.6     2052  2011
#
#    Nueva_Columna
# 0            NaN
# 1            NaN

# %% [markdown]
# ### Agregar filas

# %%
#agregué una copia del df quedando 1100 registros
df_books.append(df_books)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  Nueva_Columna
# 0                    JJ Smith          4.7    17350  2016            NaN
# 1                Stephen King          4.6     2052  2011            NaN
# 2          Jordan B. Peterson          4.7    18979  2018            NaN
# ...

# %% [markdown]
# ### Manejo de datos nulos

# %%
dict = {"Col1": [1,2,3,np.nan],
"Col2": [4,np.nan,6,7],
"Col3": ["a", "b", "c", None]}

# %%
df_ = pd.DataFrame(dict)
df_
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   NaN     b
# 2   3.0   6.0     c
# 3   NaN   7.0  None

# %%
df_.isnull() #busco valores nulos del df
# Out:
#     Col1   Col2   Col3
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3   True  False   True

# %%
df_.isnull()*1 #convierto los nulos en 1
# Out:
#    Col1  Col2  Col3
# 0     0     0     0
# 1     0     1     0
# 2     0     0     0
# 3     1     0     1

# %%
df_.fillna("Missing") #relleno los valores nulos con la palabra "Missing"
#puedo rellenar con la media por ejemplo si pongo df.mean()
# Out:
#       Col1     Col2     Col3
# 0        1        4        a
# 1        2  Missing        b
# 2        3        6        c
# 3  Missing        7  Missing

# %%
df_.interpolate() #rellena valores nulos interpolando valores según la serie
# Out:
#    Col1  Col2  Col3
# 0   1.0   4.0     a
# 1   2.0   5.0     b
# 2   3.0   6.0     c
# 3   3.0   7.0  None

# %%
df_.dropna() #elimina valores nulos
# Out:
#    Col1  Col2 Col3
# 0   1.0   4.0    a
# 2   3.0   6.0    c

# %% [markdown]
# ### Filtrado con condiciones

# %%
mayor_a_2016 = df["Year"] > 2016

# %%
df_books[mayor_a_2016]
# Out:
#                                                   Name  \
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 7                       A Gentleman in Moscow: A Novel
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# ..                                                 ...
# 544                                             Wonder
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Year  Nueva_Columna
# 2          Jordan B. Peterson          4.7    18979  2018            NaN
# 3               George Orwell          4.7    21424  2017            NaN
# 4    National Geographic Kids          4.8     7665  2019            NaN
# ...

# %%
df_books = pd.read_csv("C:/Users/Daniela/PLATZI/bestsellers-with-categories_.csv", sep = ",", header = 0)
df_books.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
genre_fiction = df_books["Genre"] == "Fiction"

# %%
df_books[genre_fiction]
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 3                               1984 (Signet Classics)        George Orwell
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                       A Gentleman in Moscow: A Novel          Amor Towles
# ..                                                 ...                  ...
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
# 543                                             Wonder        R. J. Palacio
# 544                                             Wonder        R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)          Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %%
df_books[mayor_a_2016 & genre_fiction]
# Out:
#                                                   Name             Author  \
# 3                               1984 (Signet Classics)      George Orwell
# 7                       A Gentleman in Moscow: A Novel        Amor Towles
# 10                           A Man Called Ove: A Novel    Fredrik Backman
# 13                    A Wrinkle in Time (Time Quintet)  Madeleine L'Engle
# 40            Brown Bear, Brown Bear, What Do You See?    Bill Martin Jr.
# ..                                                 ...                ...
# 509                              To Kill a Mockingbird         Harper Lee
# 529  What Should Danny Do? (The Power to Choose Ser...          Adir Levy
# 534                            Where the Crawdads Sing        Delia Owens
# 544                                             Wonder      R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)        Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %%
#Si quisiera ahora los libros menores o iguales al año 2016 niego la condición mayores a 2016 con ~
df_books[~mayor_a_2016]
# Out:
#                                                   Name               Author  \
# 0                        10-Day Green Smoothie Cleanse             JJ Smith
# 1                                    11/22/63: A Novel         Stephen King
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 9                            A Man Called Ove: A Novel      Fredrik Backman
# ..                                                 ...                  ...
# 540                                             Wonder        R. J. Palacio
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
# 543                                             Wonder        R. J. Palacio
# 546  You Are a Badass: How to Stop Doubting Your Gr...          Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# ### Funciones principales de Pandas

# %%
df_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df_books.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df_books.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
df_books.tail(3)
# Out:
#                                                   Name       Author  \
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
df_books.memory_usage(deep=True) #me da el uso de memoria de cada columna
# Out:
# Index            128
# Name           59737
# Author         39078
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          36440
# dtype: int64

# %%
df_books['Author'].value_counts()
#Muestra cuantos datos hay de cada autor
# Out:
# Jeff Kinney                           12
# Rick Riordan                          11
# Gary Chapman                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Mark Owen                              1
# Keith Richards                         1
# Thomas Campbell                        1
# David Goggins                          1
# JJ Smith                               1
# Name: Author, Length: 248, dtype: int64

# %%
df_books.drop_duplicates()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.sort_values('Year').head(3)
 #ordena los valores de menor a mayor segun el año
# Out:
#                                                   Name           Author  \
# 177                                      I, Alex Cross  James Patterson
# 131  Glenn Beck's Common Sense: The Case Against an...       Glenn Beck
# 417                                   The Last Lecture     Randy Pausch
#
#      User Rating  Reviews  Price  Year        Genre
# 177          4.6     1320      7  2009      Fiction
# 131          4.6     1365     11  2009  Non Fiction
# 417          4.7     4028      9  2009  Non Fiction

# %%
df_books.sort_values('Year', ascending=False).head(3)
#ordena los valores de mayor a menor segun el año
# Out:
#                                                   Name                 Author  \
# 549  You Are a Badass: How to Stop Doubting Your Gr...            Jen Sincero
# 294  School Zone - Big Preschool Workbook - Ages 4 ...            School Zone
# 489                   The Wonderful Things You Will Be  Emily Winfield Martin
#
#      User Rating  Reviews  Price  Year        Genre
# 549          4.7    14331      8  2019  Non Fiction
# 294          4.8    23047      6  2019  Non Fiction
# 489          4.9     8842     10  2019      Fiction

# %% [markdown]
# ### Groupby
#
# Permite agrupar datos en función de los demás. Es decir, hacer el análisis del DataFrame en función de una de las columnas.
#
# Agrupar por Author y mostrar el conteo de los datos de las demás columnas
# La columna Author, pasa a ser el índice.

# %%
df_books.groupby("Author").count()
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %%
#Agrupar por Author y mostrar la media de los datos de las demás columnas
df_books.groupby('Author').median()
# Out:
#                             User Rating  Reviews  Price    Year
# Author
# Abraham Verghese                    4.6   4866.0   11.0  2010.5
# Adam Gasiewski                      4.4   3113.0    6.0  2017.0
# Adam Mansbach                       4.8   9568.0    9.0  2011.0
# Adir Levy                           4.8   8170.0   13.0  2019.0
# Admiral William H. McRaven          4.7  10199.0   11.0  2017.0
# ...                                 ...      ...    ...     ...
# Walter Isaacson                     4.6   7827.0   20.0  2012.0
# William Davis                       4.4   7497.0    6.0  2012.5
# William P. Young                    4.6  19720.0    8.0  2013.0
# Wizards RPG Team                    4.8  16990.0   27.0  2018.0
# Zhi Gang Sha                        4.6    128.5   11.5  2011.0
#
# [248 rows x 4 columns]

# %%
#Se puede usar las funciones lambda en el método .agg(), para obtener funciones custom ya sea para modificar un valor o para filtrar valores.

#Un ejemplo puede ser el siguiente:

df_books.groupby('Author').agg({'Year':lambda x: [i-2000 for i in x], 'Reviews':lambda x: sum([i**2 for i in x])})
# Out:
#                                     Year    Reviews
# Author
# Abraham Verghese                [10, 11]   47355912
# Adam Gasiewski                      [17]    9690769
# Adam Mansbach                       [11]   91546624
# Adir Levy                           [19]   66748900
# Admiral William H. McRaven          [17]  104019601
# ...                                  ...        ...
# Walter Isaacson             [17, 11, 12]  131608054
# William Davis                   [12, 13]  112410018
# William P. Young                 [9, 17]  777756800
# Wizards RPG Team            [17, 18, 19]  865980300
# Zhi Gang Sha                     [9, 13]      49769
#
# [248 rows x 2 columns]

# %%
#La columna Author, en los casos anteriores, pasa a ser el índice.

#Podemos usar loc y acceder a un dato específico del DataFrame. Agrupar por autor y mostrar la suma de los valores de las demás columnas para William Davis
df_books.groupby('Author').sum().loc['William Davis']
# Out:
# User Rating        8.8
# Reviews        14994.0
# Price             12.0
# Year            4025.0
# Name: William Davis, dtype: float64

# %%
#Agrupar por author y mostrar la suma de los valores de las demás columnas. Colocar los índices que el DataFrame trae por defecto
#de esta manera deja de usar autor como indice
df_books.groupby('Author').sum().reset_index()
# Out:
#                          Author  User Rating  Reviews  Price  Year
# 0              Abraham Verghese          9.2     9732     22  4021
# 1                Adam Gasiewski          4.4     3113      6  2017
# 2                 Adam Mansbach          4.8     9568      9  2011
# 3                     Adir Levy          4.8     8170     13  2019
# 4    Admiral William H. McRaven          4.7    10199     11  2017
# ..                          ...          ...      ...    ...   ...
# 243             Walter Isaacson         13.7    18668     61  6040
# 244               William Davis          8.8    14994     12  4025
# 245            William P. Young          9.2    39440     16  4026
# 246            Wizards RPG Team         14.4    50970     81  6054
# 247                Zhi Gang Sha          9.2      257     23  4022
#
# [248 rows x 5 columns]

# %%
#La función agg() permite aplicar varias funciones al DataFrame una vez agrupado según una columna específica. Agrupar por Author y mostrar el mínimo y máximo de las demás columnas
df_books.groupby('Author').agg(['min','max'])
# Out:
#                                                                          Name  \
#                                                                           min
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                             Leonardo da Vinci
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# ...

# %%
#Agrupar por Author, obtener el mínimo y máximo de la columna ‘Reviews’ y sumar los valores de la columna ‘User Rating’
df_books.groupby('Author').agg({'Reviews':['min','max'], 'User Rating':'sum'})
# Out:
#                            Reviews        User Rating
#                                min    max         sum
# Author
# Abraham Verghese              4866   4866         9.2
# Adam Gasiewski                3113   3113         4.4
# Adam Mansbach                 9568   9568         4.8
# Adir Levy                     8170   8170         4.8
# Admiral William H. McRaven   10199  10199         4.7
# ...                            ...    ...         ...
# Walter Isaacson               3014   7827        13.7
# William Davis                 7497   7497         8.8
# William P. Young             19720  19720         9.2
# Wizards RPG Team             16990  16990        14.4
# Zhi Gang Sha                    37    220         9.2
#
# [248 rows x 3 columns]

# %%
#Agrupar por ‘Author - Year’ y contar los valores de las demás columnas
df_books.groupby(['Author','Year']).count()
# Out:
#                        Name  User Rating  Reviews  Price  Genre
# Author           Year
# Abraham Verghese 2010     1            1        1      1      1
#                  2011     1            1        1      1      1
# Adam Gasiewski   2017     1            1        1      1      1
# Adam Mansbach    2011     1            1        1      1      1
# Adir Levy        2019     1            1        1      1      1
# ...                     ...          ...      ...    ...    ...
# Wizards RPG Team 2017     1            1        1      1      1
#                  2018     1            1        1      1      1
#                  2019     1            1        1      1      1
# Zhi Gang Sha     2009     1            1        1      1      1
#                  2013     1            1        1      1      1
#
# [493 rows x 5 columns]

# %% [markdown]
# ### comparación de Pandas con SQL
# https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html

# %% [markdown]
# ### Combinando Dataframes
# Existen diferentes formas de fusionar dos DataFrames. Esto se hace a través de la lógica de combinación como se muestra a continuación:
# 1. Left join: Da prioridad al DataFrame de la izquierda. Trae siempre los datos de la izquierda y las filas en común con el DataFrame de la derecha.
# 2. Right join: Da prioridad al DataFrame de la derecha. Trae siempre los datos de la derecha y las filas en común con el DataFrame de la izquierda.
# 3. Inner join: Trae solamente aquellos datos que son común en ambos DataFrame
# 4. Outer join: Trae los datos tanto del DataFrame de la izquierda como el de la derecha, incluyendo los datos que comparten ambos.
#
# https://static.platzi.com/media/user_upload/merge-ab0ffccb-3ec3-44f5-94a7-c96896993212.jpg

# %%
df1 = pd.DataFrame({'A':['A0', 'A1', 'A2','A3'],
        'B':['B0', 'B1', 'B2','B3'],
	'C':['C0', 'C1', 'C2','C3'],
	'D':['D0', 'D1', 'D2','D3']})


df2 = pd.DataFrame({'A':['A4', 'A5', 'A6','A7'],
	'B':['B4', 'B5', 'B6','B7'],
	'C':['C4', 'C5', 'C6','C7'],
	'D':['D4', 'D5', 'D6','D7']})

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %% [markdown]
# ### Concat

# %%
pd.concat([df1,df2], ignore_index=True) 
#por default concatena por el axis 0 (por las filas)
#los índices heredan el índice anterior, para que no me queden indicens repetidos pongo ignore_index=True
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1,df2], axis =1) #concatena por columnas
# Out:
#     A   B   C   D   A   B   C   D
# 0  A0  B0  C0  D0  A4  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %% [markdown]
# ## Merge
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
izq
# Out:
#   key   A   B
# 0  k0  A0  B0
# 1  k1  A1  B1
# 2  k2  A2  B2
# 3  k3  A3  B3

# %%
der
# Out:
#   key   C   D
# 0  k0  C0  D0
# 1  k1  C1  D1
# 2  k2  C2  D2
# 3  k3  C3  D3

# %%
izq.merge(der, on="key")
# Out:
#   key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k1  A1  B1  C1  D1
# 2  k2  A2  B2  C2  D2
# 3  k3  A3  B3  C3  D3

# %%
#MERGE 2
izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key_2' : ['k0', 'k1', 'k2','k3'],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
#Hay diferencias entre algunas columnas, por esa razón hay que separarlos de esta manera:
izq.merge(der, left_on = 'key', right_on='key_2')
# Out:
#   key   A   B key_2   C   D
# 0  k0  A0  B0    k0  C0  D0
# 1  k1  A1  B1    k1  C1  D1
# 2  k2  A2  B2    k2  C2  D2
# 3  k3  A3  B3    k3  C3  D3

# %%
#MERGE 3

izq = pd.DataFrame({'key' : ['k0', 'k1', 'k2','k3'],
 'A' : ['A0', 'A1', 'A2','A3'],
'B': ['B0', 'B1', 'B2','B3']})

der = pd.DataFrame({'key_2' : ['k0', 'k1', 'k2',np.nan],
 'C' : ['C0', 'C1', 'C2','C3'],
'D': ['D0', 'D1', 'D2','D3']})

# %%
#Si tenemos un NaN en nuestro DataFrame, pandas no lo detectará como un mach. Se soluciona con How, dando así, una preferencia.
izq.merge(der, left_on = 'key', right_on='key_2', how='left')
#si no pongo how me hace un inner join  sólo trae la intersección entre ambos
# Out:
#   key   A   B key_2    C    D
# 0  k0  A0  B0    k0   C0   D0
# 1  k1  A1  B1    k1   C1   D1
# 2  k2  A2  B2    k2   C2   D2
# 3  k3  A3  B3   NaN  NaN  NaN

# %% [markdown]
# ### Join
# Es otra herramienta para hacer combinaciones. La diferencia entre el join y el merge es que join va a buscar el match en función de los índices y no de columnas específicas.
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html

# %%
izq = pd.DataFrame({'A': ['A0','A1','A2'],
  'B':['B0','B1','B2']},
  index=['k0','k1','k2'])

der =pd.DataFrame({'C': ['C0','C1','C2'],
  'D':['D0','D1','D2']},
  index=['k0','k2','k3'])

# %%
izq
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
der
# Out:
#      C   D
# k0  C0  D0
# k2  C1  D1
# k3  C2  D2

# %%
izq.join(der)
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %% [markdown]
# puedo poner how= "inner" "outer" "right"
# leer documentación para entender bien esto

# %%
izq.join(der, how = 'outer')
#trae todos los valores aunque no hagn match y completa con NaN
# Out:
#       A    B    C    D
# k0   A0   B0   C0   D0
# k1   A1   B1  NaN  NaN
# k2   A2   B2   C1   D1
# k3  NaN  NaN   C2   D2

# %% [markdown]
# ### Pivot_table
# Esta función puede traer recuerdos a las personas interesadas en el mundo del SQL, ya que Oracle, PostgreSQL y otros motores de bases de datos la tienen implementada desde hace muchos años. Pivot, básicamente, transforma los valores de determinadas columnas o filas en los índices de un nuevo DataFrame, y la intersección de estos es el valor resultante.
#
# Entiendo que esto puede sonar algo confuso, pero no te preocupes, todo queda mucho más claro con un ejemplo.
#
# Para comenzar, crea un nuevo Jupyter Notebooks, puedes usar Google Colab o la notebook de tu preferencia que estés utilizando para este curso.
#
# Carga el DataFrame que hemos usado en el curso:

# %%
df_books.pivot_table(index='Author',columns='Genre',values='User Rating')
# Out:
# Genre                       Fiction  Non Fiction
# Author
# Abraham Verghese                4.6          NaN
# Adam Gasiewski                  NaN     4.400000
# Adam Mansbach                   4.8          NaN
# Adir Levy                       4.8          NaN
# Admiral William H. McRaven      NaN     4.700000
# ...                             ...          ...
# Walter Isaacson                 NaN     4.566667
# William Davis                   NaN     4.400000
# William P. Young                4.6          NaN
# Wizards RPG Team                4.8          NaN
# Zhi Gang Sha                    NaN     4.600000
#
# [248 rows x 2 columns]

# %% [markdown]
# Como resultado, los valores de Author pasan a formar el índice por fila y los valores de Genre pasan a formar parte de los índices por columna, y el User Rating se mantiene como valor.
# Por supuesto, para este caso, un Author suele tener un solo género literario, así que no es una transformación muy útil, pero veamos si podemos lograr algo mejor.

# %%
df_books.pivot_table(index='Genre',columns='Year', values='User Rating',aggfunc='sum')
# Out:
# Year          2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# Genre
# Fiction      110.2   92.3   97.0   94.4  109.1  134.3   79.1   89.6  113.7
# Non Fiction  119.0  135.6  130.9  132.2  118.6   96.8  153.3  144.3  119.3
#
# Year          2018   2019
# Genre
# Fiction       99.5   96.4
# Non Fiction  133.9  140.6

# %% [markdown]
# En este caso tenemos por cada género, la suma a lo largo de los años. Esto es mucho más interesante, ¿verdad? La mejor noticia es que no solo podemos obtener la suma, también podemos obtener la media, la desviación estándar, el conteo, la varianza, etc. Únicamente con cambiar el parámetro aggfunc que traduce función de agrupamiento.

# %% [markdown]
# ### Melt
# El método melt toma las columnas del DataFrame y las pasa a filas, con dos nuevas columnas para especificar la antigua columna y el valor que traía.
#
# Por ejemplo, simplemente al imprimir las cinco primeras filas del DataFrame con las columnas de Name y Genre se tiene este resultado.
#
# Para ello ejecuta la siguiente línea en tu Jupyter Notebook:

# %%
df_books[['Name','Genre']].head(5)
# Out:
#                                                 Name        Genre
# 0                      10-Day Green Smoothie Cleanse  Non Fiction
# 1                                  11/22/63: A Novel      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  Non Fiction
# 3                             1984 (Signet Classics)      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  Non Fiction

# %%
df_books[['Name','Genre']].head(5).melt()
# Out:
#   variable                                              value
# 0     Name                      10-Day Green Smoothie Cleanse
# 1     Name                                  11/22/63: A Novel
# 2     Name            12 Rules for Life: An Antidote to Chaos
# 3     Name                             1984 (Signet Classics)
# 4     Name  5,000 Awesome Facts (About Everything!) (Natio...
# 5    Genre                                        Non Fiction
# 6    Genre                                            Fiction
# 7    Genre                                        Non Fiction
# 8    Genre                                            Fiction
# 9    Genre                                        Non Fiction

# %% [markdown]
# Ahora cada resultado de las dos columnas pasa a una fila de este modo a tipo llave:valor.
#
# En el siguiente ejemplo ejecutemos melt de esta manera:

# %%
df_books.melt(id_vars='Year',value_vars='Genre')
# Out:
#      Year variable        value
# 0    2016    Genre  Non Fiction
# 1    2011    Genre      Fiction
# 2    2018    Genre  Non Fiction
# 3    2017    Genre      Fiction
# 4    2019    Genre  Non Fiction
# ..    ...      ...          ...
# 545  2019    Genre      Fiction
# 546  2016    Genre  Non Fiction
# 547  2017    Genre  Non Fiction
# 548  2018    Genre  Non Fiction
# 549  2019    Genre  Non Fiction
#
# [550 rows x 3 columns]

# %% [markdown]
# Simplemente, podemos seleccionar las columnas que no quiero hacer melt usando el parámetro id_vars. Para este caso Year y también la única columna que quiero aplicar el melt, para este caso Genre con la propiedad value_vars.
#
# Hemos conocido pivot y melt, dos herramientas muy útiles para manipular nuestros DataFrames.

# %% [markdown]
# ### Apply
# Es un comando muy poderoso que nos deja aplicar funciones a nuestro DataFrame

# %%
def two_times(value):
    return value * 2

# %%
df_books = pd.read_csv("C:/Users/Daniela/PLATZI/bestsellers-with-categories_.csv", sep = ",", header = 0)
df_books.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
df_books['User Rating'].apply(two_times)
#Se multiplica por 2 todos los valores de la columna
# Out:
# 0      9.4
# 1      9.2
# 2      9.4
# 3      9.4
# 4      9.6
#       ...
# 545    9.8
# 546    9.4
# 547    9.4
# 548    9.4
# 549    9.4
# Name: User Rating, Length: 550, dtype: float64

# %%
df_books['User Rating2'] =df_books['User Rating'].apply(two_times) #agrego User Rating2 como nueva columna
df_books.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre  User Rating2
# 0    17350      8  2016  Non Fiction           9.4
# 1     2052     22  2011      Fiction           9.2
# 2    18979     15  2018  Non Fiction           9.4

# %%
#Apply en varias columnas con condiciones, hay que especificar a que los vamos a aplicar (filas o columnas)
df_books.apply(lambda x: x['User Rating'] * 2 if x['Genre'] == 'Fiction' else x['User Rating'], axis = 1)

#Multiplica por 2 a los datos que cumplan la condición
# Out:
# 0      4.7
# 1      9.2
# 2      4.7
# 3      9.4
# 4      4.8
#       ...
# 545    9.8
# 546    4.7
# 547    4.7
# 548    4.7
# 549    4.7
# Length: 550, dtype: float64

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...
